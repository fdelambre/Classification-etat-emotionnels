# %%
% run outils_stage.py # les fonctions perso et les imports
% matplotlib inline

# %%
#X = np.linspace(0, 30, 200)

# %%
#Y = []
#for x in X:
#    Y.append(sinus(x))

# %%
#plt.plot(X, Y)

# %%
#f, Y = affiche_fft(X, Y)

# %%
liste_fichiers = ['CW.csv', 'DE.csv', 'PCO.csv']
df_dict = import_df(liste_fichiers, dossier = 'df')

# %%
#f1, Y1 = affiche_fft(t1, Y1, Ymax=0.3, fmax=1)

# %%
#freq(f1, Y1, 1)

# %%
#f2, Y2 = affiche_fft(t2, Y2, Ymax=0.3, fmax=1)

# %%
#freq(f2, Y2, 1)

# %%
#f3, Y3 = affiche_fft(t3, Y3, Ymax=0.3, fmax=1)

# %%
for exp in ['CW', 'DE', 'PCO']:
    t, f = calcul_freq(df_dict[exp])

# %%
t, f = calcul_freq(df)

# %%
plt.plot(t, f)

# %%
t2, f2 = detect_var(t, f)

# %%
plt.plot(t2, f2)
