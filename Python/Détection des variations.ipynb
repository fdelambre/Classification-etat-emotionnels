# %%
% run outils_stage.py # les fonctions perso et les imports
% matplotlib inline

# %%
liste_fichiers = ['PCO.csv', 'CW.csv', 'DE.csv']

# %%
df_dict = import_df(liste_fichiers, dossier = 'df')

# %%
PCO = df_dict['PCO']

# %%
PCO.head(5)
# Out:
#        t  Respiration     GSR  Temperature   CFM
# 0  0.000        0.479 -42.705       22.623  58.0
# 1  0.031        0.760 -42.705       22.623  58.0
# 2  0.063        0.947 -42.705       22.636  58.0
# 3  0.094        1.126 -42.705       22.623  58.0
# 4  0.125        1.306 -42.705       22.636  58.0

# %%
GSR = PCO['GSR']
t = PCO['t']

# %%
X = GSR

# %%
t2, X2 = detect_var(t, X)
plt.plot(t2, X2)

# %%
plt.plot(t, X)

# %%
print(len(X), len(X2))
# Out:
# 48607 5453
