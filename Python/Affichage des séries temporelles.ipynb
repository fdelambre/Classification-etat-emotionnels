# %% [markdown]
# ### Imports

# %%
% run outils_stage.py # les fonctions perso et les imports
% matplotlib inline

# %% [markdown]
# ### Transformation des données en dataframes

# %%
liste_fichiers = ['HL.csv', 'DA.csv', 'CW.csv', 'AB.csv', 'FS1.csv', 'LM.csv', 'ST.csv', 'CLP.csv', 'DE.csv', 'PCO.csv', 'PCO2.csv', 'PCO3.csv']

# %%
#df_dict = import_data(liste_fichiers, dossier = 'csv_to_df')

# %%
#for exp_name, df in df_dict.items():
#    df.to_csv('../data/df/' + exp_name + '.csv', sep = ';', float_format = '%.3f', index = False)

# %% [markdown]
# ### Lecture des fichiers csv des dataframes

# %%
df_dict = import_df(liste_fichiers, dossier = 'df')      
df_dict['AB'].head(10)
# Out:
#        t  Respiration     GSR  Temperature   CFM
# 0  0.000      -10.644 -44.157       29.417  74.0
# 1  0.031      -10.379 -44.157       29.417  74.0
# 2  0.063      -10.168 -44.157       29.417  74.0
# 3  0.094       -9.981 -44.157       29.417  74.0
# 4  0.125       -9.833 -44.169       29.417  74.0
# 5  0.156       -9.692 -44.169       29.417  74.0
# 6  0.188       -9.575 -44.169       29.417  74.0
# 7  0.219       -9.482 -44.169       29.417  74.0
# 8  0.250       -9.427 -44.169       29.417  74.0
# 9  0.281       -9.435 -44.169       29.417  74.0

# %%
for exp_name, df in df_dict.items():
    plot_exp(df, exp_name)
